# %% [markdown]
# # Module-wise previous year questions asked from OOP CST 205 according to Kerala Technical University (KTU) 2019 scheme
#
# ## Module 1
#
# - What is object-oriented programming?
# - What are the different phases of the object-oriented development life cycle?
# - What are the different types of objects?
# - What is a class?
# - What is an object?
# - What is a constructor?
# - What is a destructor?
# - What is a method?
# - What is a property?
# - What is an interface?
#
# ## Module 2
#
# - What is inheritance?
# - What are the different types of inheritance?
# - What is polymorphism?
# - What are the different types of polymorphism?
# - What is overriding?
# - What is overloading?
# - What is an abstract class?
# - What is an interface?
# - What is a superclass?
# - What is a subclass?
#
# ## Module 3
#
# - What is data encapsulation?
# - What is data hiding?
# - What is data abstraction?
# - What is information hiding?
# - What is a package?
# - What is a namespace?
# - What is a protected access modifier?
# - What is a default access modifier?
# - What is a public access modifier?
# - What is a private access modifier?
#
# ## Module 4
#
# - What is a file?
# - What is a directory?
# - What is a stream?
# - What is a buffer?
# - What is a socket?
# - What is a server?
# - What is a client?
# - What is a protocol?
# - What is a port?
# - What is an IP address?
#
# ## Module 5
#
# - What is JDBC?
# - What is the difference between JDBC and Swings?
# - How do you connect to a database using JDBC?
# - How do you execute SQL statements using JDBC?
# - What is a ResultSet object?
# - How do you iterate over the results of a SQL statement using JDBC?
# - What is Swings?
# - What are the different components that are available in the Swings toolkit?
# - How do you create a graphical user interface using Swings?
# - How do you display a JFrame object in a window?
